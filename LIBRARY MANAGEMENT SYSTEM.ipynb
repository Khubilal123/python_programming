# %%
# Library Management System

# %%
library = []  

while True:
    print("\n--- Library Menu ---")
    print("1. Add Book")
    print("2. Remove Book")
    print("3. Issue Book")
    print("4. Return Book")
    print("5. Search Book")
    print("6. Show All Books")
    print("7. Exit")

    choice = input("Enter choice (1-7): ")

    if choice == "1":
        title = input("Enter book title: ")
        author = input("Enter book author: ")
        book = {"title": title, "author": author, "issued": False}
        library.append(book)
        print(f"Book '{title}' added successfully!")

    elif choice == "2":
        title = input("Enter book title to remove: ")
        found = False
        for book in library:
            if book["title"].lower() == title.lower():
                library.remove(book)
                print(f"Book '{title}' removed successfully!")
                found = True
                break
        if not found:
            print("Book not found!")

    elif choice == "3":
        title = input("Enter book title to issue: ")
        found = False
        for book in library:
            if book["title"].lower() == title.lower():
                if not book["issued"]:
                    book["issued"] = True
                    print(f"Book '{title}' has been issued.")
                else:
                    print(f"Book '{title}' is already issued.")
                found = True
                break
        if not found:
            print("Book not found!")

    elif choice == "4":
        title = input("Enter book title to return: ")
        found = False
        for book in library:
            if book["title"].lower() == title.lower():
                if book["issued"]:
                    book["issued"] = False
                    print(f"Book '{title}' has been returned.")
                else:
                    print(f"Book '{title}' was not issued.")
                found = True
                break
        if not found:
            print("Book not found!")

    elif choice == "5":
        keyword = input("Enter title or author to search: ")
        found = False
        for book in library:
            if keyword.lower() in book["title"].lower() or keyword.lower() in book["author"].lower():
                status = "Issued" if book["issued"] else "Available"
                print(f"Title: {book['title']}, Author: {book['author']}, Status: {status}")
                found = True
        if not found:
            print("No matching books found.")

    elif choice == "6":
        if not library:
            print("Library is empty!")
        else:
            print("\n--- Library Books ---")
            for book in library:
                status = "Issued" if book["issued"] else "Available"
                print(f"Title: {book['title']}, Author: {book['author']}, Status: {status}")

    elif choice == "7":
        print("Exited Library Management System.")
        break

    else:
        print("Invalid choice! Please try again.")
# Out:
# --- Library Menu ---
# 1. Add Book
# 2. Remove Book
# 3. Issue Book
# 4. Return Book
# 5. Search Book
# 6. Show All Books
# 7. Exit
# Enter choice (1-7):  7
# Exited Library Management System.

# %%
library = []

def add_book():
    title = input("Enter book title: ")
    author = input("Enter book author: ")
    book = {"title": title, "author": author, "issued": False}
    library.append(book)
    print(f"Book '{title}' added successfully!")

def remove_book():
    title = input("Enter book title to remove: ")
    for book in library:
        if book["title"].lower() == title.lower():
            library.remove(book)
            print(f"Book '{title}' removed successfully!")
            return
    print("Book not found!")

def issue_book():
    title = input("Enter book title to issue: ")
    for book in library:
        if book["title"].lower() == title.lower():
            if not book["issued"]:
                book["issued"] = True
                print(f"Book '{title}' has been issued.")
            else:
                print(f"Book '{title}' is already issued.")
            return
    print("Book not found!")

def return_book():
    title = input("Enter book title to return: ")
    for book in library:
        if book["title"].lower() == title.lower():
            if book["issued"]:
                book["issued"] = False
                print(f"Book '{title}' has been returned.")
            else:
                print(f"Book '{title}' was not issued.")
            return
    print("Book not found!")

def search_book():
    keyword = input("Enter title or author to search: ")
    found = False
    for book in library:
        if keyword.lower() in book["title"].lower() or keyword.lower() in book["author"].lower():
            status = "Issued" if book["issued"] else "Available"
            print(f"Title: {book['title']}, Author: {book['author']}, Status: {status}")
            found = True
    if not found:
        print("No matching books found.")

def show_books():
    if not library:
        print("Library is empty!")
    else:
        print("\n--- Library Books ---")
        for book in library:
            status = "Issued" if book["issued"] else "Available"
            print(f"Title: {book['title']}, Author: {book['author']}, Status: {status}")


# Main loop
while True:
    print("\n--- Library Menu ---")
    print("1. Add Book")
    print("2. Remove Book")
    print("3. Issue Book")
    print("4. Return Book")
    print("5. Search Book")
    print("6. Show All Books")
    print("7. Exit")

    choice = input("Enter choice (1-7): ")

    if choice == "1":
        add_book()
    elif choice == "2":
        remove_book()
    elif choice == "3":
        issue_book()
    elif choice == "4":
        return_book()
    elif choice == "5":
        search_book()
    elif choice == "6":
        show_books()
    elif choice == "7":
        print("Exited Library Management System.")
        break
    else:
        print("Invalid choice! Please try again.")
# Out:
# --- Library Menu ---
# 1. Add Book
# 2. Remove Book
# 3. Issue Book
# 4. Return Book
# 5. Search Book
# 6. Show All Books
# 7. Exit
# Enter choice (1-7):  1
# Enter book title:  harry potter and the philophers stone
# Enter book author:  jk rowling
# Book 'harry potter and the philophers stone' added successfully!
#
# --- Library Menu ---
# 1. Add Book
# 2. Remove Book
# 3. Issue Book
# 4. Return Book
# 5. Search Book
# 6. Show All Books
# 7. Exit
# Enter choice (1-7):  6
# --- Library Books ---
# Title: harry potter and the philophers stone, Author: jk rowling, Status: Available
#
# --- Library Menu ---
# 1. Add Book
# 2. Remove Book
# 3. Issue Book
# 4. Return Book
# 5. Search Book
# 6. Show All Books
# 7. Exit
# Enter choice (1-7):  3
# Enter book title to issue:  harry potter and the philophers stone
# Book 'harry potter and the philophers stone' has been issued.
#
# --- Library Menu ---
# 1. Add Book
# 2. Remove Book
# 3. Issue Book
# 4. Return Book
# 5. Search Book
# 6. Show All Books
# 7. Exit
