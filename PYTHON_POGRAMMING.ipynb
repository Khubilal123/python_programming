# %% [markdown]
# # Day 1

# %%
print("Hello Khubi");
# Out:
# Hello Khubi

# %%
a = 100
b = 3.14
c = True
d = "khubi"

print(type(a))
print(type(b))
print(type(c))
print(type(d))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'bool'>
# <class 'str'>

# %% [markdown]
# # project

# %%
num1 = float (input("Enter your first number"))
num2 = float (input("Enter your second number"))

print(f'First no is' ,num1,'and second no is',num2)
print("Addition is :",num1+num2)
print("Subtraction is :",num1-num2)
# Out:
# Enter your first number 20
# Enter your second number 20
# First no is 20.0 and second no is 20.0
# Addition is : 40.0
# Subtraction is : 0.0

# %% [markdown]
# # celsius to degree

# %%
c = float(input("Enter the temperature : "))
f = ((c*1.8) +32)
print("Your temperature in F is ",f)
# Out:
# Enter the temperature :  30
# Your temperature in F is  86.0

# %% [markdown]
# # cm to m and vice versa

# %%
value1 = float(input("Enter value to be converted:"))
f1 = (value1/100)
f2 = (value2*100)
print(input("Enter your choice:"))
if choice ==f1:
print("Your value in m is ",f1)
else:
print("Your value in cm is ",f2)
# Out:
#   Cell In[159], line 6
#     print("Your value in m is ",f1)
#     ^
# IndentationError: expected an indented block after 'if' statement on line 5

# %%
value1 = float(input("Enter value to be converted to m: "))
value2 = float(input("Enter value to be converted to cm: "))
f1 = (value1/100)
f2 = (value2*100)
choice = f1
print("Enter your choice:")

print("Your value in m is ",f1)
print("Your value in cm is ",f2)
# Out:
# Enter value to be converted to m:  20
# Enter value to be converted to cm:  20
# Your value in m is  0.2
# Your value in cm is  2000.0

# %% [markdown]
# # day 2

# %%
age = int(input("Enter Your Age"))
if age > 18 :
    print("You can watch the movie")
else:
    print("Not allowed")
# Out:
# Enter Your Age 20
# You can watch the movie

# %%
age = int(input("Enter Your Age"))
ticket=True
if age > 18 :
    print("You can watch the movie")
    if ticket == True :
        print("you can go")
    elif age<15:
        print("Show your id")
else:
    print("Not allowed")
# Out:
# Enter Your Age 20
# You can watch the movie
# you can go

# %%
age = 18
if age > 20 and age <20 :
    print("Both Are True")
else:
    print("No any one was false")
# Out:
# No any one was false

# %%
if age<10 or age>15:
    print("Any one was True")
# Out:
# Any one was True

# %%
for i in range(5):
     print ("1")
# Out:
# 1
# 1
# 1
# 1
# 1

# %%
for i in range(2,10):
    print(i)
# Out:
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %%
for i in range(2,10,2):
    print(i)
# Out:
# 2
# 4
# 6
# 8

# %%
for i in range(10,1,-2):
    print(i)
# Out:
# 10
# 8
# 6
# 4
# 2

# %%
for i in range(5):
    print("*"*i)
# Out:
# *
# **
# ***
# ****

# %%
for j in range(5,0,-1):
   print("*"*j)
# Out:
# *****
# ****
# ***
# **
# *

# %%
for i in range(5):
    print('*'*i)
    for i in range(10,0,1):
      print('*'*i)
# Out:
# *
# **
# ***
# ****

# %%
number=int(input("Enter your number:"))
if number%2==0:
  print("Your number is even")
else:
    print("Your number is odd")
# Out:
# Enter your number: 30
# Your number is even

# %%
n= 16361
j= float(n/10000)
print(j)
# Out:
# 1.6361

# %%
balance=5000
pin=1234
user_pin = (input("Enter your pin:")

# %% [markdown]
# # DAY 3

# %%
mylist = ["apple","banana","oranges"]

# %%
print(mylist[0])
# Out:
# apple

# %%
print(mylist[1:2])
# Out:
# ['banana']

# %%
mylist.append("cherry")

# %%
print(mylist)
# Out:
# ['apple', 'banana', 'oranges', 'cherry']

# %%
mylist.insert(1,"blueberry")

# %%
print(mylist)
# Out:
# ['apple', 'blueberry', 'banana', 'oranges', 'cherry']

# %%
mylist.count("apple")
# Out:
# 1

# %%
mylist.append("apple")

# %%
mylist.count("apple")
# Out:
# 2

# %%
print(mylist)
# Out:
# ['apple', 'apple', 'banana', 'blueberry', 'cherry', 'oranges']

# %%
mylist.sort()

# %%
print(mylist)
# Out:
# ['apple', 'apple', 'banana', 'blueberry', 'cherry', 'oranges']

# %%
mylist.pop(1)
# Out:
# 'apple'

# %%
print(mylist)
# Out:
# ['apple', 'banana', 'blueberry', 'cherry', 'oranges']

# %%
mylist.remove("banana")

# %%
print(mylist)
# Out:
# ['apple', 'blueberry', 'cherry', 'oranges']

# %%
mylist.clear()

# %%
print(mylist)
# Out:
# []

# %%
mylist = ["apple","banana","oranges"]

# %%
mylist.reverse()

# %%
print(mylist)
# Out:
# ['oranges', 'banana', 'apple']

# %%
mytuple = ("1","2","3")

# %%
type(mytuple)
# Out:
# tuple

# %%
mytuple.index("1")
# Out:
# 0

# %%
mytuple.count("1")
# Out:
# 1

# %%
setmy={1,2,3,4,5}

# %%
type(setmy)
# Out:
# set

# %%
print(setmy)
# Out:
# {1, 2, 3, 4, 5}

# %%
set1 = {1,3}
set2 = {1,4}

# %%
print(set1 | set2)
# Out:
# {1, 3, 4}

# %%
print(set1 & set2)
# Out:
# {1}

# %%
set1.clear()

# %%
print(set1)
# Out:
# set()

# %%
student = {"name":"Tom","age":20}

# %%
type(student)
# Out:
# dict

# %%
student.keys()
# Out:
# dict_keys(['name', 'age'])

# %%
student.items()
# Out:
# dict_items([('name', 'Tom'), ('age', 20)])

# %%
student.pop("name")
# Out:
# 'Tom'

# %%
print(student)
# Out:
# {'age': 20}

# %%
student.values()
# Out:
# dict_values([20])

# %%
text = "Hello Khubi"

# %%
print(text[0:5])
# Out:
# Hello

# %%
print(text.find("Khubi"))
# Out:
# 6

# %%
text = input("enter your word:")
if text ==("stupid"):
     print("stu***")
else:
     print("text")
# Out:
# enter your word: stupid
# stu***

# %%
text = "hello khubi"
print(text.split())
# Out:
# ['hello', 'khubi']

# %%
text2  = ['hi','students']

# %%
print(text2)
# Out:
# ['hi', 'students']

# %%
print("".join(text2))
# Out:
# histudents

# %%
file = open("Doc.txt","w")

# %%
file.write("hello i am written in python code!")
# Out:
# 34

# %%
file.close()

# %%
file = open("Doc.txt","r")
print(file.read())
file.close()
# Out:
# hello i am written in python code!

# %%
with open("Doc.txt","w") as f:
    f.write("Hello

# %% [markdown]
# # DAY 4
# functions

# %%
def print_name():
    print("Tom")

# %%
print_name()
# Out:
# Tom

# %%
def print_name(a):
    print(f'HI, {a}')

# %%
print_name('tom')
# Out:
# HI, tom

# %%
print_name('jack')
# Out:
# HI, jack

# %%
def multi_arg(*arg):
    print(arg)

# %%
multi_arg(1,2,3)
# Out:
# (1, 2, 3)

# %%
def add(a,b,c):
    return a + b+ c

# %%
add(1,3,1)
# Out:
# 5

# %%
def student(**info):
    for key , value in info.items():
        print(key ,":",  value)

# %%
student(name="Tom",contact = 123)
# Out:
# name : Tom
# contact : 123

# %%
def myfunc(a,b):
    return a+b , a-b

# %%
myfunc(1,3)
# Out:
# (4, -2)

# %%
double = lambda  x : x * 2

# %%
print (double(5))
# Out:
# 10

# %%
sq = lambda x: x ** 2
print(sq(3))
# Out:
# 9

# %%
add = lambda x: x++x
print(add(3))
# Out:
# 6

# %%
multiply=lambda x: x**x
print(multiply(4))
# Out:
# 256

# %%
pip install tools
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import math

# %%
from math import sqrt

# %%
sqrt(25)
# Out:
# 5.0

# %%
import random as r

# %%
r.randint(1,20)
# Out:
# 6

# %%
import datetime as d

# %%
print(d.datetime.today())
# Out:
# 2025-11-21 12:44:43.770738

# %%
try :
    no = int(input(" Enter a n umber"))
    print = (10 / 10)
# Out:
#   Cell In[35], line 3
#     print = (10 / 10)
#                      ^
# _IncompleteInputError: incomplete input

# %%
no = int("Enter a n umber")
print = (10 / no)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 no = int("Enter a n umber")
#       2 print = (10 / no)
#
# ValueError: invalid literal for int() with base 10: 'Enter a n umber'

# %%
try :
    no = int(input("Enter a n umber"))
    print = (10 / no)
except ZerodivisionError:
    print("don't enter 0")
except ValueError:
    print("Enter only int")
# Out:
# Enter a n umber 1.1
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 2
#       1 try :
# ----> 2     no = int(input("Enter a n umber"))
#       3     print = (10 / no)
#
# ValueError: invalid literal for int() with base 10: '1.1'
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 4
#       2     no = int(input("Enter a n umber"))
#       3     print = (10 / no)
# ----> 4 except ZerodivisionError:
#       5     print("don't enter 0")
#       6 except ValueError:
#
# NameError: name 'ZerodivisionError' is not defined

# %% [markdown]
# # Day 5

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt

# %%
x = [1,2,3,4,5]
y = [10,20,30,40,50]

# %%
plt.plot(x,y)
plt.title("Student hrs marks")
plt.xlabel("Hrs")
plt.ylabel("Marks")
plt.show()

# %%
subject = ["M1", "M2", "CHEM", "PHYSICS"]
marks = ["15","19","21","16"]

plt.bar(subject,marks)
plt.title("Student hrs marks")
plt.xlabel("Subject")
plt.ylabel("Marks")
plt.show()

# %%
seeds = [10,20,30]
grown = [12,14,16]
not_grown = [8,6,14]
plt.plot(seeds, grown,not_grown, linestyle='--', color='blue')
plt.title("a line graph comparing growth of seeds")
plt.xlabel("number of seeds")
plt.ylabel("number of seeds grown")
plt.show()

# %%
pip install pyttsx3
# Out:
# ...
#   Using cached pyttsx3-2.99-py3-none-any.whl.metadata (6.2 kB)
# ...
#   Using cached comtypes-1.4.13-py3-none-any.whl.metadata (7.2 kB)
# ...
#   Using cached pypiwin32-223-py3-none-any.whl.metadata (236 bytes)
# ...
# Using cached pyttsx3-2.99-py3-none-any.whl (32 kB)
# Using cached comtypes-1.4.13-py3-none-any.whl (254 kB)
# Using cached pypiwin32-223-py3-none-any.whl (1.7 kB)
# ...
#
#    ------------- -------------------------- 1/3 [comtypes]
#    ------------- -------------------------- 1/3 [comtypes]
#    ------------- -------------------------- 1/3 [comtypes]
#    ------------- -------------------------- 1/3 [comtypes]
#    ------------- -------------------------- 1/3 [comtypes]
#    ------------- -------------------------- 1/3 [comtypes]
#    ------------- -------------------------- 1/3 [comtypes]
#    ------------- -------------------------- 1/3 [comtypes]
#    ------------- -------------------------- 1/3 [comtypes]
#    ------------- -------------------------- 1/3 [comtypes]
# ...

# %%
import pyttsx3

# %%
speaker = pyttsx3.init()
speaker.say("Welcome Khubi")
speaker.runAndWait()

# %%
pip install SpeechRecognition
# Out:
# ...
#   Using cached standard_aifc-3.13.0-py3-none-any.whl.metadata (969 bytes)
# ...
#   Using cached standard_chunk-3.13.0-py3-none-any.whl.metadata (860 bytes)
# ...
#    ---------------------------------------- 0.0/32.9 MB ? eta -:--:--
#    ---------------------------------------- 0.3/32.9 MB ? eta -:--:--
#    - -------------------------------------- 1.0/32.9 MB 3.4 MB/s eta 0:00:10
#    --- ------------------------------------ 2.6/32.9 MB 5.3 MB/s eta 0:00:06
#    ----- ---------------------------------- 4.2/32.9 MB 6.1 MB/s eta 0:00:05
#    ------- -------------------------------- 6.3/32.9 MB 7.0 MB/s eta 0:00:04
#    --------- ------------------------------ 8.1/32.9 MB 7.4 MB/s eta 0:00:04
#    ------------ --------------------------- 10.2/32.9 MB 7.9 MB/s eta 0:00:03
#    -------------- ------------------------- 11.8/32.9 MB 8.1 MB/s eta 0:00:03
#    ----------------- ---------------------- 14.2/32.9 MB 8.3 MB/s eta 0:00:03
# ...

# %%
pip install pyAudio
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import speech_recognition as sr

# %%
mic = sr.Recognizer()

# %%
with sr.Microphone() as source:
    print("start speaking...")
    voice = mic.listen(source)
    text = mic.recognize_google(voice)
    print("You said this : ",text)
# Out:
# start speaking...
# You said this :  hello how are you

# %%
pip install pywhatkit
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Preparing metadata (setup.py): started
# ...

# %%
import pywhatkit

# %%
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement subprocess (from versions: none)
# ERROR: No matching distribution found for subprocess

# %%
import webbrowser

# %%
webbrowser.open_new_tab("https://learning.hash13.com/")
# Out:
# True

# %%
import os

# %%
current_directory = os.getcwd()
print(f"Current working directory: {current_directory}")
# Out:
# Current working directory: C:\Users\Admin\Documents\internship

# %%
import os
import speech_recognition as sr
import pyttsx3
import matplotlib.pyplot as plt
import webbrowser
import subprocess

speaker = pyttsx3.init()
mic = sr.Recognizer()

speaker.say("welcome to jarvis")
speaker.runAndWait()

with sr.Microphone() as source:
    print("start speaking...")
    voice = mic.listen(source)
    
    text = mic.recognize_google(voice)
    print(f"You said: {text}")
    if "open notepad" in text.lower():
        print("Opening notepad...")
        os.system("notepad")
# Out:
# start speaking...
# You said: open WhatsApp Notepad and notepad

# %% [markdown]
# # day 6

# %%
from flask import Flask

# %%
app = Flask(__name__)

@app.route("/")
def home():
    return """
    <!DOCTYPE html>
<html lang="en">
<head>
  <!--
    Resume Index File for: Khuse
    Notes:
    - Single-file, print-ready resume (A4), responsive, and ATS-friendly
    - Semantic HTML for better parsing
    - Minimal, clean typography with accessible contrast
    - Edit placeholders in CONTACT + LINKS section
  -->
  <meta charset="UTF-8" />
  <meta name="viewport" content="width=device-width, initial-scale=1" />
  <title>Khubi — Resume</title>

  <style>
    :root {
      --bg: #ffffff;
      --fg: #0f172a;      /* slate-900 */
      --muted: #475569;   /* slate-600 */
      --accent: #2563eb;  /* blue-600 */
      --line: #e2e8f0;    /* slate-200 */
      --chip-bg: #eef2ff; /* indigo-50 */
      --chip-fg: #3730a3; /* indigo-800 */
    }

    * { box-sizing: border-box; }
    html, body {
      background: var(--bg);
      color: var(--fg);
      font-family: Inter, system-ui, -apple-system, Segoe UI, Roboto, Ubuntu, Cantarell, "Helvetica Neue", Arial, "Noto Sans", sans-serif;
      line-height: 1.55;
      margin: 0;
      padding: 0;
    }

    /* Layout */
    .page {
      max-width: 1024px;
      margin: 24px auto;
      padding: 24px;
    }

    header {
      display: grid;
      grid-template-columns: 1fr auto;
      gap: 16px;
      align-items: center;
      border-bottom: 2px solid var(--line);
      padding-bottom: 16px;
      margin-bottom: 16px;
    }

    .title h1 {
      font-size: 2rem;
      margin: 0;
      letter-spacing: 0.2px;
    }

    .title p {
      margin: 4px 0 0 0;
      color: var(--muted);
      font-weight: 500;
    }

    .contact {
      text-align: right;
      font-size: 0.95rem;
    }

    .contact a {
      color: var(--accent);
      text-decoration: none;
    }

    /* Sections */
    section {
      margin: 18px 0;
      padding-top: 6px;
    }

    section h2 {
      font-size: 1.1rem;
      margin: 0 0 10px 0;
      font-weight: 700;
      text-transform: uppercase;
      letter-spacing: 0.8px;
      color: var(--muted);
    }

    .item {
      margin-bottom: 12px;
      padding-bottom: 12px;
      border-bottom: 1px solid var(--line);
    }

    .item:last-child { border-bottom: none; padding-bottom: 0; }

    .item-header {
      display: grid;
      grid-template-columns: 1fr auto;
      gap: 8px;
      align-items: baseline;
    }

    .role {
      font-weight: 600;
    }

    .meta {
      color: var(--muted);
      font-size: 0.95rem;
    }

    .desc {
      margin: 6px 0 0 0;
    }

    /* Lists and chips */
    ul {
      margin: 6px 0 0 18px;
    }

    .chips {
      display: flex;
      flex-wrap: wrap;
      gap: 6px;
      margin-top: 6px;
    }

    .chip {
      background: var(--chip-bg);
      color: var(--chip-fg);
      border: 1px solid #c7d2fe;
      padding: 4px 8px;
      border-radius: 12px;
      font-size: 0.85rem;
      white-space: nowrap;
    }

    /* Utilities */
    .muted { color: var(--muted); }
    .link { color: var(--accent); text-decoration: none; }
    .nowrap { white-space: nowrap; }

    /* Print styling */
    @page { size: A4; margin: 14mm; }
    @media print {
      .page { margin: 0; padding: 0; }
      .controls { display: none !important; }
      .chip { border-color: #b6c1ff; }
    }

    /* Top controls (optional) */
    .controls {
      display: flex;
      gap: 8px;
      margin-bottom: 10px;
    }
    .btn {
      border: 1px solid var(--line);
      background: #f8fafc;
      color: var(--fg);
      padding: 6px 10px;
      border-radius: 6px;
      font-size: 0.95rem;
      cursor: pointer;
    }
    .btn:hover { background: #eef2f7; }
  </style>
</head>

<body>
  <div class="page">
    <!-- Quick controls: Print or Download as PDF (via browser print) -->
    <div class="controls">
      <button class="btn" onclick="window.print()">Print / Save as PDF</button>
      <button class="btn" onclick="toggleCompact()">Toggle compact</button>
    </div>

    <!-- Header -->
    <header>
      <div class="title">
        <h1>Khubilal Javat</h1>
        <p>AI/ML-oriented full‑stack builder • Hardware/software integration • Hackathon innovator</p>
      </div>
      <div class="contact">
        <!-- Replace with your details -->
        <div>Jaipur, Rajasthan, India</div>
        <div><span class="nowrap">Email:</span> <a href="mailto:your.email@example.com">your.email@example.com</a></div>
        <div><span class="nowrap">Phone:</span> +91-XXXXXXXXXX</div>
        <div>
          <a href="https://github.com/Khubilal123" class="link">GitHub</a> ·
          <a href="https://www.linkedin.com/in/Khubilal-Javat" class="link">LinkedIn</a> ·
          <a href="https://your-portfolio.example.com" class="link">Portfolio</a>
        </div>
      </div>
    </header>

    <!-- Summary -->
    <section id="summary">
      <h2>Summary</h2>
      <div class="item">
        <p class="desc">
          Resourceful, modular thinker combining AI/ML, full‑stack engineering, and hardware integration.
          Experienced in rapid prototyping, clear documentation, and deploying scalable, assignment‑ready solutions.
          Driven by originality, sustainability, and real‑world impact across hackathons and academic projects.
        </p>
        <div class="chips">
          <span class="chip">Python</span>
          <span class="chip">C++</span>
          <span class="chip">Java</span>
          <span class="chip">JavaScript</span>
          <span class="chip">SQL</span>
          <span class="chip">Flask</span>
          <span class="chip">MongoDB</span>
          <span class="chip">ESP32‑CAM</span>
          <span class="chip">Cloud APIs</span>
          <span class="chip">AI/ML</span>
        </div>
      </div>
    </section>

    <!-- Skills -->
    <section id="skills">
      <h2>Skills</h2>
      <div class="item">
        <div class="item-header">
          <div class="role">Languages & frameworks</div>
          <div class="meta">Python, C++, Java, JavaScript, SQL, Flask, modern JS frameworks</div>
        </div>
        <ul>
          <li>Strong data structures, algorithms, and modular design for production‑ready code</li>
          <li>Hands‑on with REST APIs, cloud integrations, and deployment workflows</li>
          <li>Clear, assignment‑grade documentation and stepwise explanations</li>
        </ul>
      </div>
      <div class="item">
        <div class="item-header">
          <div class="role">Systems & tooling</div>
          <div class="meta">Git, CI/CD basics, troubleshooting, cost/time estimation</div>
        </div>
        <ul>
          <li>End‑to‑end planning, iterative prototyping, and rapid pivots</li>
          <li>Hardware/software integration (ESP32‑CAM, IoT), sustainable design</li>
          <li>Database CRUD patterns (MongoDB), authentication, and scalable backends</li>
        </ul>
      </div>
    </section>

    <!-- Experience (add internships, roles, or major contributions) -->
    <section id="experience">
      <h2>Experience</h2>

      <!-- Example entry (replace with real roles) -->
      <div class="item">
        <div class="item-header">
          <div class="role">Student Developer • Full‑stack & AI Projects</div>
          <div class="meta">Jaipur, India · 2024–Present</div>
        </div>
        <ul>
          <li>Delivered assignment‑ready ML notes and neural network docs with clarity and academic standards</li>
          <li>Built modular voice assistant (Jarvis) in Python: extensible command handlers, system utilities, and API integrations</li>
          <li>Practiced MongoDB CRUD and query syntax; integrated backend patterns into student projects</li>
        </ul>
        <p class="muted">Environment: Python, Flask, JS, MongoDB, Git, Cloud APIs</p>
      </div>
    </section>

    <!-- Projects -->
    <section id="projects">
      <h2>Selected projects</h2>

      <div class="item">
        <div class="item-header">
          <div class="role">Solar‑powered ESP32‑CAM AI crop disease detector</div>
          <div class="meta">Prototype • 2025</div>
        </div>
        <p class="desc">
          Designed a cost‑effective, solar‑powered IoT system using ESP32‑CAM for field‑level crop disease detection.
          Implemented edge capture, cloud inference, and dashboard reporting with full BoM, cost/time breakdown, and scalability plan.
        </p>
        <ul>
          <li>Modular pipeline: capture → preprocess → inference → alert → dashboard</li>
          <li>Optimized power budget and connectivity for rural deployment</li>
          <li>Hackathon‑ready documentation, diagrams, and deployment notes</li>
        </ul>
        <p class="muted">Tech: ESP32‑CAM, Python, Flask API, Cloud inference, MQTT/HTTP, Solar design</p>
      </div>

      <div class="item">
        <div class="item-header">
          <div class="role">Lost‑and‑found web app</div>
          <div class="meta">Frontend → Full‑stack • 2024–2025</div>
        </div>
        <p class="desc">
          Evolved from a dynamic HTML/CSS/JS frontend with localStorage to a full‑stack app with backend and database integration.
          Implemented CRUD flows, authentication, and clean UI for campus use.
        </p>
        <ul>
          <li>Reusable components and state management for reports and claims</li>
          <li>Backend routes for items, users, and moderation</li>
          <li>Scalable data model and deployment checklist</li>
        </ul>
        <p class="muted">Tech: JS, CSS, Flask/Express, MongoDB, Git</p>
      </div>

      <div class="item">
        <div class="item-header">
          <div class="role">Chess clips automation engine</div>
          <div class="meta">Creative coding • 2025</div>
        </div>
        <p class="desc">
          Automated creation of viral chess clips with Stockfish eval, AI‑powered commentary, and creative modes (Brilliancy Reel, Meme Mode).
          Integrated agent‑based workflows and upload automation.
        </p>

  
    """
@app.route("/about")
def about():
    return """
    <h1> I am Home page</h1>
    <h2>I am running in flask</h2>

    """
if __name__=='__main__':
    app.run()
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [23/Nov/2025 12:25:08] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [23/Nov/2025 12:27:43] "GET / HTTP/1.1" 200 -

# %%
pip install pygame
# Out:
# ...
#   Using cached pygame-2.6.1-cp313-cp313-win_amd64.whl.metadata (13 kB)
# Using cached pygame-2.6.1-cp313-cp313-win_amd64.whl (10.6 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pygame
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.13.5)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
pygame.init()
# Out:
# (5, 0)

# %%
screen = pygame.display.set_mode((600,600))

# %%
pygame.display.set_caption("X/O GAME")

# %%
WHITE = (255,255,255)
BLACK = (0,0,0)
size = 200

# %%
board = [["","",""],
        ["","",""],
        ["","",""]]

# %%
player = "x"

# %%
font = pygame.font.Font(None,100)

# %%
run = True

# %%
while run:
    screen.fill(WHITE)
    pygame.draw.line(screen,BLACK,(200,0),(200,600),5)
    pygame.draw.line(screen,BLACK,(400,0),(400,600),5)
    pygame.draw.line(screen,BLACK,(0,200),(600,200),5)
    pygame.draw.line(screen,BLACK,(0,400),(600,400),5)
    for row in range(3):
        for col in range(3):
             if board[row][col] != "":
                 text = font.render(board[row][col],True)
        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                run = False
            if event.type == pygame.MOUSEBUTTONDOWN:
                mouse_x , mouse_y = pygame.mouse.get_pos()
                row = mouse_y//200
                col = mouse_x//200
                if board[row][col]=="":
                   board[row][col]==player
                   if player == "X":
                    player = "O"
                   else:
                      player = "X"
    pygame.display.update()
pygame.quit()

# %%
import pygame 
pygame.init()
screen = pygame.display.set_mode((600,600))
pygame.display.set_caption("X/O GAME")
WHITE = (255,255,255)
BLACK = (0,0,0)
size = 200
board = [["","",""],
        ["","",""],
        ["","",""]]
player = "x"
font = pygame.font.Font(None,100)
run = True
while run:
    screen.fill(WHITE)
    pygame.draw.line(screen,BLACK,(200,0),(200,600),5)
    pygame.draw.line(screen,BLACK,(400,0),(400,600),5)
    pygame.draw.line(screen,BLACK,(0,200),(600,200),5)
    pygame.draw.line(screen,BLACK,(0,400),(600,400),5)
    for row in range(3):
        for col in range(3):
             if board[row][col] != "":
                 text = font.render(board[row][col],True)
        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                run = False
            if event.type == pygame.MOUSEBUTTONDOWN:
                mouse_x , mouse_y = pygame.mouse.get_pos()
                row = mouse_y//200
                col = mouse_x//200
                if board[row][col]=="":
                   board[row][col]==player
                   if player == "X":
                    player = "O"
                   else:
                      player = "X"
    pygame.display.update()
pygame.quit()

# %% [markdown]
# # Day 7

# %%
import http.server

# %%
import socketserver

# %%
PORT = 8000

# %%
handler = http.server.SimpleHTTPRequestHandler

# %%
with socketserver.TCPServer(("",PORT), handler) as http:
    print("Server is running on port",PORT)
    http.serve_forever()
# Out:
# Server is running on port 8000
# 10.71.123.148 - - [24/Nov/2025 11:48:01] "GET / HTTP/1.1" 200 -

# %%
 pip install streamlit
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import streamlit as st

# %%
st.title("Streamlit app of vgu")
st.text("welcome to our dashboard")
st.write("You can write")
st.title("Streamlit app of vgu")
name = st.text_input("Enter your name : ")
age = st.number_input("Enter your age :")
st.write("Your name is ", name, "Your age is ", age)
st.selectbox("Enter your course:",["BCA","BTECH","MCA"])
if st.button("CLICK ME"):
    st.success("Clicked Button")
# Out:
# 2025-11-24 13:54:52.108 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 13:54:52.124 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 13:54:52.135 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 13:54:52.147 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 13:54:52.157 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 13:54:52.164 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-24 13:54:52.170 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...

# %% [markdown]
# # DAY 9

# %%
pip install smtplib
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement smtplib (from versions: none)
# ERROR: No matching distribution found for smtplib

# %%
import smtplib
import ssl
from email.message import EmailMessage
EMAIL= "Yourgmail@gmail.com"
APP_PASSWORD= "Your password"
RECEIVER= "receiver@gmail.com "
msg = EmailMessage()
msg["From"] = EMAIL
msg["To"] = RECEIVER
msg["Subject"] = "Hello from Python...."
msg.set_content("The email was shared by python code...")
context = ssl.create_context()
with smtplib.SMTP_SSL("smtp.gmail.com",465, context=context) as server:
    server.login(EMAIL,APP_PASSWORD)
    server.send_message(msg)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 12
#      10 msg["Subject"] = "Hello from Python...."
#      11 msg.set_content("The email was shared by python code...")
# ---> 12 context = ssl.create_context()
#      13 with smtplib.SMTP_SSL("smtp.gmail.com",465, context=context) as server:
#      14     server.login(EMAIL,APP_PASSWORD)
#
# AttributeError: module 'ssl' has no attribute 'create_context'

# %%
pip install twilio
# Out:
# ...
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ----------------- ---------------------- 0.8/1.8 MB 4.6 MB/s eta 0:00:01
#    ---------------------------------------  1.8/1.8 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  1.8/1.8 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  1.8/1.8 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  1.8/1.8 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  1.8/1.8 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------- 1.8/1.8 MB 1.0 MB/s eta 0:00:00
# ...
#
#    ---------------------------------------- 0/2 [aiohttp-retry]
#    ---------------------------------------- 0/2 [aiohttp-retry]
#    -------------------- ------------------- 1/2 [twilio]
#    -------------------- ------------------- 1/2 [twilio]
#    -------------------- ------------------- 1/2 [twilio]
#    -------------------- ------------------- 1/2 [twilio]
# ...

# %%
from twilio.rest import
